# %%
import sonde3
import pandas

# %%
metadata, df = sonde3.read_ysi("tests/ysi_test_files/SA08.dat")
# Out:
# C:\Users\ETurner\Desktop\python\sonde3
# Info: No time zone was set for file, assuming records are recorded in EST

# %%
df.head()
# Out:
#              Datetime_(UTC)     _TempC    _CmS/cm     _Depm        _DO%  \
# 0 2008-07-16 11:56:31+00:00  28.998718   0.000037  0.010862   93.391418
# 1 2008-07-16 12:56:31+00:00  28.482361   0.000059  0.016358   96.765137
# 2 2008-07-16 13:56:31+00:00  27.257385   0.000546  0.017263  103.529358
# 3 2008-07-16 14:56:31+00:00  29.507751  21.301758  0.542648   93.055725
# 4 2008-07-16 15:56:31+00:00  29.762268  21.454102  0.557098   94.188690
#
#     _BattV
# 0  6.09375
# 1  6.09375
# 2  6.09375
# 3  6.09375
# 4  6.09375

# %%
df.round({'_TempC': 2, '_Depm': 3, '_DO%':1})
# Out:
#                Datetime_(UTC)  _TempC    _CmS/cm  _Depm   _DO%    _BattV
# 0   2008-07-16 11:56:31+00:00   29.00   0.000037  0.011   93.4  6.093750
# 1   2008-07-16 12:56:31+00:00   28.48   0.000059  0.016   96.8  6.093750
# 2   2008-07-16 13:56:31+00:00   27.26   0.000546  0.017  103.5  6.093750
# 3   2008-07-16 14:56:31+00:00   29.51  21.301758  0.543   93.1  6.093750
# 4   2008-07-16 15:56:31+00:00   29.76  21.454102  0.557   94.2  6.093750
# 5   2008-07-16 16:56:31+00:00   30.09  21.589355  0.563   97.2  6.093750
# 6   2008-07-16 17:56:31+00:00   30.36  21.918457  0.577   98.8  6.093750
# 7   2008-07-16 18:56:31+00:00   30.78  22.248535  0.569  106.4  6.093750
# 8   2008-07-16 19:56:31+00:00   30.90  22.152344  0.570  109.6  6.093750
# 9   2008-07-16 20:56:31+00:00   30.58  21.929199  0.555  104.7  6.093750
# 10  2008-07-16 21:56:31+00:00   30.49  21.901367  0.582  103.0  6.093750
# 11  2008-07-16 22:56:31+00:00   30.53  21.941895  0.585  104.5  6.093750
# ...

# %%
csv = pandas.read_csv("tests/ysi_test_files/SA08.CDF")

# %%
csv.head()
# Out:
#          Date      Time   Temp  SpCond  Depth   ODO% Battery    Cond ODO Conc  \
# 0       M/D/Y  hh:mm:ss      C   mS/cm      m      %       V   mS/cm     mg/L
# 1  07/16/2008  07:00:31  29.00   0.000  0.011   93.4     6.1   0.000     7.18
# 2  07/16/2008  08:00:31  28.48   0.000  0.016   96.8     6.1   0.000     7.51
# 3  07/16/2008  09:00:31  27.26   0.001  0.017  103.5     6.1   0.001     8.21
# 4  07/16/2008  10:00:31  29.51  19.613  0.543   93.1     6.1  21.302     6.66
#
#   Resistivity Salinity     TDS
# 0     KOhm.cm      ppt     g/L
# 1    26854.29    -0.00   0.000
# 2    16950.16    -0.00   0.000
# 3     1830.82    -0.00   0.000
# 4        0.05    11.60  12.749

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 12 columns):
# Date           701 non-null object
# Time           701 non-null object
# Temp           701 non-null object
# SpCond         701 non-null object
# Depth          701 non-null object
# ODO%           701 non-null object
# Battery        701 non-null object
# Cond           701 non-null object
# ODO Conc       701 non-null object
# Resistivity    701 non-null object
# Salinity       701 non-null object
# TDS            701 non-null object
# dtypes: object(12)
# memory usage: 65.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
# Datetime_(UTC)    700 non-null datetime64[ns, UTC]
# _TempC            700 non-null float64
# _CmS/cm           700 non-null float64
# _Depm             700 non-null float64
# _DO%              700 non-null float64
# _BattV            700 non-null float64
# dtypes: datetime64[ns, UTC](1), float64(5)
# memory usage: 32.9 KB
